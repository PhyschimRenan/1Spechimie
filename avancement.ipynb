# %% [markdown]
# # <center>  Activité : Evolution d’un système chimique

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2ème partie : Déterminer la composition de l’état final de n’importe quel système

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <b>2.1.</b> Vous souhaitez automatiser votre travail afin d’adapter vos calculs à n’importe quelle quantité de matière de chaque espèce chimique.
# Pour vous aider, une amie informaticienne vous a préparé, en suivant vos conseils, une ébauche de programme écrit ci-dessous en langage Python.
# N’y connaissant pas grand-chose à la chimie, elle vous laisse le soin de compléter les zones manquantes dans le programme en utilisant les valeurs de la 1ère partie puis elle vous demande de le tester.

# %% [markdown]
# ### <div class="alert alert-success" role="alert"> Ci-dessous, compléter les coefficients stoechiométriques des réactifs et des produits puis exécuter la cellule en cliquant sur le bouton de la barre de menu plus haut.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# Déclaration des coefficients stoechiométriques

cs_Fe2O3 = **

cs_CO = **

cs_CO2 = **

cs_Fe = **
# Out:
#   File "<ipython-input-1-bbf0ea063880>", line 6
#     cs_Fe2O3 = **
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### <div class="alert alert-success" role="alert">Ci-dessous, compléter les quantités initiales de réactifs et de produits puis exécuter la cellule.

# %%
# Initialisation des quantités de matières initiales (en mol)

no_Fe2O3 = **

no_CO = **

no_CO2 = **

no_Fe = **

# %% [markdown]
# ### <div class="alert alert-success" role="alert"> Compléter la ligne 11 ci-dessous puis noter sur votre compte rendu la méthode utilisée par le programme pour déterminer l'avancement maximal. Ne pas oublier d'exécuter la cellule.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <center><b>Remarque :</b> Pour faire apparaitre les numéros de lignes, cliquer, dans la barre de menu, sur View puis Toggle line Numbers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# - - - - - - - - - - - - - - - - - -

# Déclarations des fonctions

# - - - - - - - - - - - - - - - - - -

def avancement_max(no_Fe2O3, no_CO) : #fonction qui permet de calculer Xmax

    x_max_Fe2O3 = no_Fe2O3 / cs_Fe2O3

    x_max_CO = ***************

    x_max = min(x_max_CO,x_max_Fe2O3)

    return(x_max)

# %% [markdown]
# ### <div class="alert alert-success" role="alert"> Compléter les lignes 10 , 12 et 14 sur le modèle  de la ligne 8. Noter sur votre compte rendu à quelle partie du tableau d'avancement elle se rapporte. Ne pas oublier d'exécuter la cellule.

# %%
# Calcul de l'avancement maximum

x_max = avancement_max(no_Fe2O3, no_CO)
# Création des listes

avancement = [ 0, x_max ]

n_Fe2O3 = [ (no_Fe2O3-cs_Fe2O3*x) for x in avancement]

n_CO = [ (**************) for x in avancement]

n_CO2 = [ (***************) for x in avancement]

n_Fe = [ (**************) for x in avancement]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ### Exécuter la dernière partie du programme ci-dessous.
# &nbsp;
#
# ### Expliquer, sur votre compte rendu, l'intérêt du graphique obtenu.

# %%
def changerEchelles(event) :

    x_max, n_max = changerCourbes(event)

    ax.axis([0,x_max,0,n_max])

# - - - - - - - - - - - - - - - - - -

# Corps du programme

# - - - - - - - - - - - - - - - - - -

# Calcul de l'avancement maximum

x_max = avancement_max(no_Fe2O3, no_CO)


# Création des courbes

fig, ax = plt.subplots()

fig.subplots_adjust(left=0.25, bottom=0.25)

(courbe1,) = ax.plot(avancement, n_Fe2O3, label="Fe2O3", color='orange')

(courbe2,) = ax.plot(avancement, n_CO, label="CO", color='red')

(courbe3,) = ax.plot(avancement, n_CO2, label="CO2", color='black')

(courbe4,) = ax.plot(avancement, n_Fe, label="Fe", color='blue')

# Réglages axes et grille

liste_des_n_max = [ max(n_Fe2O3), max(n_CO), max(n_CO2), max(n_Fe) ]

n_max = max(liste_des_n_max)

plt.xlabel("Avancement (mol)")

plt.ylabel("Quantité de matière (mol)")

plt.title("Evolution de la réaction de combustion")

plt.legend(loc='upper center')

plt.axis([0,x_max,0,n_max])

plt.grid()

# Création de l'image

nom_du_fichier = "courbes_avancement_"+str(no_Fe2O3)+str(no_CO)

plt.savefig(nom_du_fichier+".png")

# Affichage de l'interface

plt.show()

# %% [markdown]
# # A la fin du programme, penser à sauvegarder votre travail !
# ![image.png](attachment:image.png)

# %% [markdown]
# # Si le logiciel ne répond plus, cliquer sur le lien initial, attendre la fin du chargement de la page  puis cliquer sur le nuage Restaurer
# ![image.png](attachment:image.png)
